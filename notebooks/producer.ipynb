# %%
from pathlib import Path
from confluent_kafka import SerializingProducer
from confluent_kafka.serialization import StringSerializer
from confluent_kafka.schema_registry import SchemaRegistryClient
from confluent_kafka.schema_registry.protobuf import ProtobufSerializer
from faker import Faker
import time
import random
import os
import sys

# Load environment variables from .env file
from dotenv import load_dotenv
dotenv_path = Path('/resources/.env')
load_dotenv(dotenv_path=dotenv_path)

# Access environment variables
project_name = os.getenv('COMPOSE_PROJECT_NAME')
kafka_host = os.getenv('KAFKA_HOST')
topic_name = os.getenv('KAFKA_TOPIC_NAME')
replication_factor = int(os.getenv('KAFKA_REPLICATION'))
num_partitions = int(os.getenv('KAFKA_PARTITION'))
schema_registry_host = os.getenv('SCHEMA_REG_HOST')

# Protobuf schema import
sys.path.append('./protobuf')
import protobuf_schema_pb2 

# Kafka Configuration
bootstrap_servers = f'{kafka_host}:9092' 
schema_registry_url = f'http://{schema_registry_host}:8081' 

# Producer Configuration
producer_conf = {
    'bootstrap.servers': bootstrap_servers,
    'key.serializer': StringSerializer('utf_8'),
}

# Schema Registry and Protobuf Serializer
schema_registry_client = SchemaRegistryClient({'url': schema_registry_url})

protobuf_serializer = ProtobufSerializer(protobuf_schema_pb2.EmployeeSalary, 
                                         schema_registry_client, 
                                         {'use.deprecated.format': False})

producer_conf['value.serializer'] = protobuf_serializer

# Kafka Producer
producer = SerializingProducer(producer_conf)
fake = Faker()

def generate_salary_data():
    salary_data = protobuf_schema_pb2.EmployeeSalary()
    salary_data.employee_id = fake.uuid4()
    salary_data.employee_name = fake.name()
    salary_data.salary = round(random.uniform(30000, 100000), 2) 
    salary_data.department = fake.random_element(elements=('HR', 'IT', 'Finance', 'Marketing', 'Sales'))
    return salary_data

while True:
    salary_data = generate_salary_data()
    print(salary_data)
    producer.produce(topic=topic_name, key=salary_data.employee_id, value=salary_data)
    producer.flush()
    time.sleep(5)
# Out:
# employee_id: "410a0bb7-57f6-4a11-bdd9-6ffadf2f709c"
# employee_name: "Steven Walker"
# salary: 32188.04
# department: "IT"
#
# employee_id: "9ad2e6d0-2533-4057-bc53-4df09cb078a1"
# employee_name: "Aaron Marquez"
# salary: 50587.96
# department: "HR"
#
# employee_id: "8163ae9e-6d98-4590-8d6b-57277c7a9ce6"
# employee_name: "Justin Orozco"
# salary: 58461.64
# department: "Marketing"
#
# employee_id: "7839a5c3-adc5-48fa-8c2f-29941dca2028"
# employee_name: "Dalton Boyd"
# salary: 98559.27
# department: "Finance"
#
# employee_id: "8b4b7ee7-3228-432e-9a21-b2e817af4719"
# employee_name: "Robin Martin"
# salary: 69884.6
# department: "IT"
#
# employee_id: "5ab46cf4-b9fa-4281-8597-fe952bf8319d"
# employee_name: "Emily Murillo"
# salary: 66204.15
# department: "HR"
#
# employee_id: "ce2b3937-797b-47f6-b448-0ec363dfd0d6"
# employee_name: "John Chavez"
# salary: 92322.2
# department: "Sales"
#
# employee_id: "7c5c820d-e926-4ca2-8f34-abbe68e775a5"
# employee_name: "Darrell Green"
# salary: 79241.1
# department: "Sales"
#
# employee_id: "7a6727be-ae4b-4ed0-a1b9-13b76e2dbda6"
# employee_name: "James Davis"
# salary: 94583.5
# department: "IT"
#
# employee_id: "1bbaeab6-c48f-4d8a-a96e-342daeef437c"
# employee_name: "Alexis Curtis"
# salary: 45451.67
# department: "IT"
#
# employee_id: "ec1ef445-c313-4092-af32-3e877fae9e87"
# employee_name: "Timothy Davis"
# salary: 85454.2
# department: "Sales"
#
# employee_id: "44a23dee-d3be-404d-881b-000621ef48f6"
# employee_name: "Mr. Patrick Lyons"
# salary: 69574.46
# department: "Sales"
#
# employee_id: "f19cff0b-d351-4e6c-a070-fab81a318759"
# employee_name: "Victor Padilla"
# salary: 42868.25
# department: "HR"
#
# employee_id: "5b7c4085-8400-40bd-b528-0430f55bace1"
# employee_name: "Joshua Palmer"
# salary: 73034.68
# department: "IT"
#
# employee_id: "eea08ab9-169a-4587-8e7a-a18640d2dec9"
# employee_name: "Frances Williams"
# salary: 53099.18
# department: "Sales"
#
# employee_id: "1147eba4-81d5-4105-9ede-099308d60588"
# employee_name: "Megan Olson"
# salary: 61053.46
# department: "Sales"
#
# employee_id: "3efe4a96-8985-40d8-a91c-4d675448237c"
# employee_name: "Gabriel Davis"
# salary: 64728.78
# department: "Finance"
#
# employee_id: "338cd4ad-476c-469c-b1ea-51ccf8a34eaf"
# employee_name: "David Hardin"
# salary: 99219.12
# department: "Sales"
#
# employee_id: "8755e18d-35e5-4de4-a07c-df974dabad65"
# employee_name: "Michael Rivera"
# salary: 61898.57
# department: "Sales"
#
# employee_id: "73df7573-ca12-4bcd-85d3-3b8036dd6bb4"
# employee_name: "Cameron Oneill"
# salary: 76649.64
# department: "Finance"
#
# employee_id: "387d6160-378d-4afb-b14b-e8431ed2c3fc"
# employee_name: "Crystal Hubbard"
# salary: 40191.52
# department: "Sales"
#
# employee_id: "d75b610e-d397-4c41-9627-e2c86c75837a"
# employee_name: "Zachary Jefferson"
# salary: 65364.77
# department: "HR"
#
# employee_id: "964d0d89-af45-46e6-93ac-ffb852cfffde"
# employee_name: "Tanya Hayden"
# salary: 30553.27
# department: "HR"
#
# employee_id: "2277549d-a0d2-4f17-a198-b3fc6fdc3243"
# employee_name: "Robert Fowler"
# salary: 82670.91
# department: "Sales"
#
# employee_id: "8100d5d4-e2cb-490b-9fc7-f25c864a6a15"
# employee_name: "Francisco Clark"
# salary: 77374.78
# department: "HR"
#
# employee_id: "9fbfa76d-2df8-451a-99cd-6ba6e0fae52d"
# employee_name: "Kelly Garrett"
# salary: 88879.44
# department: "Sales"
#
# employee_id: "c218e88f-6289-43a4-bea6-dd7e5a4f1c0b"
# employee_name: "Tina White"
# salary: 58294.2
# department: "IT"
#
# employee_id: "f4e2700d-d036-4bc2-9576-b7f9a68db42c"
# employee_name: "Daniel Ross"
# salary: 55109.19
# department: "Sales"
#
# employee_id: "75105f8a-2787-4f82-aa6f-049fef3632fa"
# employee_name: "Shelly Lewis"
# salary: 92280.54
# department: "Sales"
#
# employee_id: "6cf86357-4cfe-4791-9b29-85056fdbda5d"
# employee_name: "Denise Schneider"
# salary: 38555.52
# department: "HR"
#
# employee_id: "383589b8-4ce3-4851-a3de-5f60dd236eb5"
# employee_name: "Kyle Perez"
# salary: 93389.4
# department: "Finance"
#
# employee_id: "3d1de48e-97be-4fa3-830d-5deabd0b9e8c"
# employee_name: "Raven Wilson"
# salary: 80172.63
# department: "Marketing"
#
# employee_id: "ea4c3cb1-2a19-438b-b9ef-f70ae6b3f909"
# employee_name: "Andrea Brown"
# salary: 62082.11
# department: "Marketing"
#
# employee_id: "8360dc09-0a2d-45c7-8009-214dbdaefce1"
# employee_name: "Angela Miller"
# salary: 84795.23
# department: "Sales"
#
# employee_id: "44e08a66-f804-442d-8484-156ffaddd82f"
# employee_name: "Carolyn Taylor"
# salary: 39869.56
# department: "HR"
#
# employee_id: "1eefe38f-1e9b-4263-99b6-fc63ef3f24f1"
# employee_name: "Brandi Dennis"
# salary: 83485.86
# department: "HR"
#
# employee_id: "6f8b6540-4c78-4ec3-9e19-1a22ada2c442"
# employee_name: "Wayne Watkins"
# salary: 44980.66
# department: "HR"
#
# employee_id: "18490f38-f420-4539-a9aa-92c64b1aad27"
# employee_name: "Beverly Padilla"
# salary: 63428.42
# department: "Sales"
#
# employee_id: "43639c6c-f4a4-46bb-a98b-3d3d1b9537f6"
# employee_name: "Anthony Valdez"
# salary: 69988.65
# department: "Marketing"
#
# employee_id: "d83ea803-ac9d-44ce-89ea-614ea4d1d423"
# employee_name: "Jamie Johnson"
# salary: 98403.01
# department: "Marketing"
#
# employee_id: "fa21d04a-6ba0-4a4e-a815-a4969ba088b8"
# employee_name: "Jordan Mcmillan"
# salary: 70128.24
# department: "Finance"
#
# employee_id: "3411fe68-518f-4301-9a84-5d58cbe94fdc"
# employee_name: "Steven Perry"
# salary: 99008.36
# department: "HR"
#
# employee_id: "156c0b94-8550-4e95-9877-5bb0285f4afe"
# employee_name: "Omar Smith"
# salary: 97502.25
# department: "IT"
#
# employee_id: "d93db509-4fd1-4a27-ac8c-8dbe22a421aa"
# employee_name: "Alejandro Johnson"
# salary: 64987.45
# department: "IT"
#
# employee_id: "96564b69-c08d-4e50-b630-c9754226fc1f"
# employee_name: "Michael Collins"
# salary: 34884.88
# department: "Finance"
#
# employee_id: "9c178d47-c80f-4b1b-8f0b-ac7e7aa69638"
# employee_name: "Anthony Bryant"
# salary: 52609.22
# department: "HR"
#
# employee_id: "97b4cb91-6623-4351-95c8-9ff777838427"
# employee_name: "Keith Morgan"
# salary: 62945.42
# department: "Finance"
#
# employee_id: "6455476d-8697-46e2-9d1c-03a929049b42"
# employee_name: "Erica Thomas"
# salary: 47188.05
# department: "Sales"
#
# employee_id: "10ae7cb9-c60c-4645-a193-bac708f27c10"
# employee_name: "Paul Short"
# salary: 49389.39
# department: "Sales"
#
# employee_id: "0e85353a-95df-42fe-9be7-d1ebdf25a67c"
# employee_name: "Robin Jenkins"
# salary: 57465.92
# department: "Sales"
#
# employee_id: "c40110eb-c5d5-4b9b-9a4b-ba2f73dba610"
# employee_name: "Keith Decker"
# salary: 79969.93
# department: "Marketing"
#
# employee_id: "acfcdbc7-a51b-45e7-84e7-f37236f8aec4"
# employee_name: "Bryan Fields"
# salary: 79002.4
# department: "Sales"
#
# employee_id: "ea06d786-9abe-46b6-b140-269aec54d39e"
# employee_name: "Carolyn Harrison"
# salary: 49352.89
# department: "Marketing"
#
# employee_id: "78d1b17b-93c2-4e5c-9add-7bd8154d0088"
# employee_name: "Sean Mccarty"
# salary: 97018.64
# department: "IT"
#
# employee_id: "84e86960-2876-4938-b5df-c96d870b7e0c"
# employee_name: "Janet Black"
# salary: 72652.05
# department: "Sales"
#
# employee_id: "b3fc464b-ee24-4cc2-a7aa-b3b453f376b2"
# employee_name: "Bryan Patton"
# salary: 66674.55
# department: "Finance"
#
# employee_id: "e6622ff1-e43f-47ce-8ef9-fe21203bfbed"
# employee_name: "Antonio Bailey"
# salary: 49836.47
# department: "Finance"
#
# employee_id: "4495be05-14c7-4b2f-b90d-b78fb7669a86"
# employee_name: "Sean Hart"
# salary: 54182.67
# department: "Marketing"
#
# employee_id: "a5fa81c7-7639-41fc-a43d-e3f4a0fb78e5"
# employee_name: "Douglas Martinez DDS"
# salary: 80545.25
# department: "HR"
#
# employee_id: "e890d9d5-0333-4ad0-8e70-e75fcaf1b172"
# employee_name: "Melissa Zuniga"
# salary: 38213.55
# department: "HR"
#
# employee_id: "40de333c-d927-4195-882c-c74bda0cf167"
# employee_name: "Chelsea Browning"
# salary: 91868.6
# department: "Sales"
#
# employee_id: "3191fea0-2ae8-46c2-9a8b-4a9e7d4ac7b9"
# employee_name: "Brian Mccarty"
# salary: 67764.57
# department: "IT"
#
# employee_id: "c6eb8db2-4e4a-4a88-a278-19da51adcaa4"
# employee_name: "Kara Martin"
# salary: 51797.1
# department: "Sales"
#
# employee_id: "1de08e0e-5b19-4269-85f7-e598e5cb1ae7"
# employee_name: "Jill Wagner"
# salary: 46061.77
# department: "Marketing"
#
# employee_id: "e1f7e846-e138-4960-b3c9-7821a8a71a72"
# employee_name: "Joseph Soto"
# salary: 37181.51
# department: "HR"
#
# employee_id: "eb7f68ff-df66-4d9d-9cd6-5e1cf9bf89b7"
# employee_name: "Monica May"
# salary: 49706.92
# department: "Marketing"
#
# employee_id: "4b678ed6-95c1-4f72-ad07-9091f2e467cb"
# employee_name: "Joann Gray"
# salary: 76957.63
# department: "Sales"
#
# employee_id: "5215ce0e-3575-470e-bbcb-bb34eb7c8dff"
# employee_name: "Kimberly Thomas"
# salary: 76022.75
# department: "Sales"
#
# employee_id: "06a241a8-6c08-4dd1-ac60-6d903ebf0f77"
# employee_name: "Rachel Alvarez"
# salary: 73841.42
# department: "IT"
#
# employee_id: "8b9a7579-67ad-4701-af4a-a7c311e3f899"
# employee_name: "Kristina Flowers"
# salary: 71204.21
# department: "Finance"
#
# employee_id: "8f25d52d-90ad-4c76-a8e5-b466582ad109"
# employee_name: "Debra Henry"
# salary: 71103.83
# department: "HR"
#
# employee_id: "d04702bc-e9b7-47be-b16a-0b75edb7aa11"
# employee_name: "Andrea Burns"
# salary: 68359.19
# department: "Sales"
#
# employee_id: "49e0d163-08fd-477b-af9a-2ad5ae11b1a3"
# employee_name: "Stephen Jones"
# salary: 76714.55
# department: "Marketing"
#
# employee_id: "634c5aa2-6b64-475a-bf2a-039bb60006ec"
# employee_name: "Lauren Ward"
# salary: 72629.0
# department: "Finance"
#
# employee_id: "82a9287f-03b9-4d07-9e9e-fefd7e5afa8e"
# employee_name: "Darren Potts"
# salary: 30170.61
# department: "Marketing"
#
# employee_id: "947583eb-9a32-4e14-8fbe-978dd83a7035"
# employee_name: "Christine Hoffman"
# salary: 52110.92
# department: "HR"
#
# employee_id: "1d01e409-87b2-4bfe-b648-6f15ae9de982"
# employee_name: "Peter Gonzalez"
# salary: 87800.1
# department: "HR"
#
# employee_id: "3bc57e0c-20f6-4fd0-82e2-5cc7790b3daf"
# employee_name: "Craig Thompson"
# salary: 90226.14
# department: "Finance"
#
# employee_id: "0f7dc566-9297-476e-951c-3e0cfa5356d6"
# employee_name: "Joel Foster"
# salary: 73129.6
# department: "IT"
#
# employee_id: "de28c24b-84fc-4315-8441-ebe63d632434"
# employee_name: "Megan Rodriguez"
# salary: 88833.01
# department: "IT"
#
# employee_id: "be802d87-cd69-4ee8-8411-401fa867901b"
# employee_name: "Mark Smith"
# salary: 88125.86
# department: "Sales"
#
# employee_id: "18db1d57-441f-4331-93d8-773842eadaf1"
# employee_name: "Leslie Cohen"
# salary: 64505.07
# department: "IT"
#
# employee_id: "5e02fad0-2bf3-452f-ab2a-f8623397254b"
# employee_name: "Jerry Myers"
# salary: 43733.46
# department: "Marketing"
#
# employee_id: "d51240f2-b5a8-4bbc-8712-42a0ce1b56b3"
# employee_name: "Steven Sims"
# salary: 58010.54
# department: "Marketing"
#
# employee_id: "dbefe86c-01ca-460f-b969-06a05abf6b19"
# employee_name: "Sheryl Miles"
# salary: 67642.04
# department: "HR"
#
# employee_id: "92a0a77c-811b-433d-9f26-937f83876127"
# employee_name: "Cynthia Swanson"
# salary: 88686.69
# department: "Marketing"
#
# employee_id: "3221425f-1ac3-4d33-a436-cd61b17cd77c"
# employee_name: "Stephanie Burns"
# salary: 46061.59
# department: "IT"
#
# employee_id: "ebdcd1a0-111a-4af3-99c4-bef92704c7d0"
# employee_name: "Cindy Price"
# salary: 76492.33
# department: "Finance"
#
# employee_id: "0f10a326-d555-4153-81ce-6d73d8f38db9"
# employee_name: "Krista Andrade"
# salary: 76054.31
# department: "Marketing"
#
# employee_id: "87c7ce90-4722-482a-9528-67a5a35a91a4"
# employee_name: "Robert Kramer"
# salary: 72997.92
# department: "Finance"
#
# employee_id: "6f5e3c0c-68f2-4b8a-80fb-f024b6e25b98"
# employee_name: "Jill Dean"
# salary: 46356.88
# department: "HR"
#
# employee_id: "f02def65-88f1-4891-9a8d-774b64df35ca"
# employee_name: "Lance Smith"
# salary: 31676.85
# department: "HR"
#
# employee_id: "6165f9dd-aa7b-4470-94e2-877d1a9ad122"
# employee_name: "Miguel Rogers"
# salary: 72510.87
# department: "Marketing"
#
# employee_id: "c16591e4-886b-4754-86ac-be80148789ed"
# employee_name: "Tiffany Smith"
# salary: 35047.45
# department: "Finance"
#
# employee_id: "e8b3666b-3167-4326-80e9-c5bb849f87ac"
# employee_name: "Carl Moran"
# salary: 55738.91
# department: "Finance"
#
# employee_id: "0c2251fc-9b14-4087-b3d5-01bba99a5715"
# employee_name: "David Brennan"
# salary: 94466.85
# department: "HR"
#
# employee_id: "018b0a05-f125-4b9f-b3d3-6322a409be0a"
# employee_name: "Lisa Wilkerson"
# salary: 79910.41
# department: "Finance"
#
# employee_id: "f909e820-8087-41c8-b878-afa50fc90533"
# employee_name: "Sophia Johnson"
# salary: 48723.3
# department: "Finance"
#
# employee_id: "293dbfdc-49b3-4880-b063-df64a78d80f6"
# employee_name: "Dustin Thompson"
# salary: 46942.24
# department: "HR"
#
# employee_id: "64770e2e-9279-4f44-92d0-f661551894e2"
# employee_name: "Anthony Benson"
# salary: 72262.7
# department: "Finance"
#
# employee_id: "630fbe94-b344-40c2-b070-ef1d2ca56624"
# employee_name: "Caroline Lee"
# salary: 89921.7
# department: "Finance"
#
# employee_id: "46d79724-c506-4633-b2d2-ee44c8f5461d"
# employee_name: "David Mathews"
# salary: 42661.95
# department: "Finance"
#
# employee_id: "d6eab627-1b63-4b4b-b3bd-6bdd16dd2d78"
# employee_name: "Joseph Patel"
# salary: 51583.86
# department: "Finance"
#
# employee_id: "f6b89306-b101-4b2c-ba30-a13821997dd8"
# employee_name: "Guy Scott"
# salary: 50132.5
# department: "Sales"
#
# employee_id: "04c367db-7574-422f-9745-7bd88836be16"
# employee_name: "Anthony Taylor"
# salary: 56158.24
# department: "IT"
#
# employee_id: "6bd43024-235e-4b00-b45e-ed2433fbd9e6"
# employee_name: "Paula Pierce"
# salary: 75403.48
# department: "IT"
#
# employee_id: "4d5ebd71-01c4-4fb9-8271-b9213c6bd812"
# employee_name: "Daniel Kim"
# salary: 46942.69
# department: "HR"
#
# employee_id: "88960c75-de6e-4c1e-bd9e-9216f6aa6b45"
# employee_name: "Michelle Long"
# salary: 68516.44
# department: "Finance"
#
# employee_id: "49e88c7c-df0f-41b4-b77e-b7c5f434670f"
# employee_name: "Karen Fisher"
# salary: 51210.83
# department: "Sales"
#
# employee_id: "f0e1a6e8-698f-48d2-86f3-0ebf528d8a75"
# employee_name: "Felicia Potter"
# salary: 87472.68
# department: "HR"
#
# employee_id: "404bb869-40f8-4ab8-8c98-1a93532c1009"
# employee_name: "Brandon Warren"
# salary: 59575.24
# department: "HR"
#
# employee_id: "5b5863db-eb12-4a3f-bb16-0f8fffe64f29"
# employee_name: "Bonnie Walker"
# salary: 76536.81
# department: "Sales"
#
# employee_id: "e28c98a5-e8ac-4234-b7d8-d0762d4c5ab0"
# employee_name: "Kathleen Hill"
# salary: 54336.2
# department: "HR"
#
# employee_id: "1179ec44-7edc-4f68-b7b3-ebc719812231"
# employee_name: "Jennifer Wilson"
# salary: 50195.52
# department: "IT"
#
# employee_id: "7eae899a-3e69-49ca-8ad5-28075185c62b"
# employee_name: "Deborah Spencer"
# salary: 70233.96
# department: "Marketing"
#
# employee_id: "e79a317c-5219-43d2-9540-6ebc7e28665e"
# employee_name: "Evan Mclean"
# salary: 61761.65
# department: "Marketing"
#
# employee_id: "4275d112-f5b8-402c-88a9-73ba6ca92e1c"
# employee_name: "Tammy Johnson"
# salary: 76072.17
# department: "IT"
#
# employee_id: "33622fab-3081-4c63-8600-32ef0cfbd0f1"
# employee_name: "Taylor Obrien"
# salary: 54893.16
# department: "Finance"
#
# employee_id: "8e2a7ffa-e5de-4a15-a74f-0650e93e851b"
# employee_name: "Carmen Hernandez"
# salary: 74757.58
# department: "HR"
#
# employee_id: "93813f08-a953-49b6-a3bb-4767fed5f78d"
# employee_name: "Trevor Arnold"
# salary: 52694.72
# department: "IT"
#
# employee_id: "cf568cfc-c3e5-49e1-96b2-502e72835b20"
# employee_name: "Matthew Chavez"
# salary: 71798.78
# department: "IT"
#
# employee_id: "ab72cb24-8a30-4555-8cc2-a689d06f9ac5"
# employee_name: "Christina Graham"
# salary: 75716.13
# department: "HR"
#
# employee_id: "83a90a33-7c09-4c0d-b7e3-fad6dad5a0e3"
# employee_name: "Karen Perez"
# salary: 82098.98
# department: "Marketing"
#
# employee_id: "4203dd5a-aa48-4c7b-b530-e0db30bc50ec"
# employee_name: "Jesus Gomez"
# salary: 92807.97
# department: "IT"
#
# employee_id: "a1d418be-6ee2-458d-9655-254a71823dea"
# employee_name: "Laura Hayes"
# salary: 30011.33
# department: "IT"
#
# employee_id: "c2e7d316-7972-4e5f-88e4-b82dd915208f"
# employee_name: "Kaitlyn Davis"
# salary: 35090.4
# department: "Sales"
#
# employee_id: "c91e0f91-5d14-47b6-b107-86688b58d190"
# employee_name: "Dustin Webb"
# salary: 57668.94
# department: "HR"
#
# employee_id: "ce2787e1-9286-40bf-a6fc-a5d4d05264d3"
# employee_name: "Kelly Pena"
# salary: 71356.33
# department: "Marketing"
#
# employee_id: "64ab2467-c7d4-4c78-b340-02019817c133"
# employee_name: "Oscar Trujillo"
# salary: 72947.06
# department: "IT"
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 65
#      63 producer.produce(topic=topic_name, key=salary_data.employee_id, value=salary_data)
#      64 producer.flush()
# ---> 65 time.sleep(5)
#
# KeyboardInterrupt:
